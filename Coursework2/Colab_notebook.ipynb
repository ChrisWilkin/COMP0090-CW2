# %% [markdown]
# Highly recommend adding google drive to file explorer, so you can edit in an IDE, then run here https://www.technorms.com/71573/add-google-drive-to-file-explorer

# %% [markdown]
# You have to "mount" your google drive, to use command line commands

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# cd into whereever you saved your scripts (or want to save them, remember to manually add the data)

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/COMP0090-CW2/Coursework2/scripts
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/COMP0090-CW2/Coursework2/scripts
# engine.py		       R-CNN_test.py
# MTL2Bodyk12lr01ep5.pt	       R-CNN_training.py
# MTL2ROIk12lr0001ep5.pt	       R-CNN_trainingv2.py
# MTL2Segk12lr01ep5.pt	       SimpleRoI_training.py
# MTL_ROI_losses.csv	       Unet_mid_cls_test.py
# MTL_segment_losses.csv	       U_net_mid_cls_train.py
# MTL_testing.py		       Unet_test_all_data.py
# MTL_testv3.py		       Unet_test.py
# MTL_training.py		       Unet_training_all_data.py
# MTL_training_seg_accuracy.csv  Unet_training.py
# MTL_trainingv2.py	       YOLO_training.py
# MTL_trainingv3.py

# %% [markdown]
# Perform git commands like this

# %%
# !git clone https://github.com/ChrisWilkin/COMP0090-CW2.git

# %%
# !git status
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# Run python scripts like this (make sure you have selected GPU under "Runtime -> Change Runtime type")

# %%
# !python MTL_trainingv3.py
# Out:
# Loading Data...
# Finished Loading Data (19.53s)
# Loading Data...
# Finished Loading Data (6.13s)
#
# EPOCH  0
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3635: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Batch 24/917
# Average 25 Batch Seg Loss:  0.5809105872650605
# Average 25 Batch ROI Loss:  0.4913148453357962
# 25 Batches: 20.24s
# Batch 49/917
# Average 25 Batch Seg Loss:  0.5273457454505659
# ...
